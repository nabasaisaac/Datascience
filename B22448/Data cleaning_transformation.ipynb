# %% [markdown]
# ## Data cleaning and transformation ##

# %% [markdown]
# ### RECAP!, importing and reading dataset, basic exploration

# %%
import pandas as pd
import numpy as np
import seaborn as sns # 'sns' is the conventional alias for seaborn
import matplotlib.pyplot as plt # For generating visuals
# %matplotlib inline

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.2)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Downloading matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading contourpy-1.3.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.54.1-cp312-cp312-win_amd64.whl.metadata (167 kB)
#      ---------------------------------------- 0.0/167.0 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/167.0 kB 660.6 kB/s eta 0:00:01
#      ------ ------------------------------ 30.7/167.0 kB 660.6 kB/s eta 0:00:01
#      ------ ------------------------------ 30.7/167.0 kB 660.6 kB/s eta 0:00:01
#      --------- --------------------------- 41.0/167.0 kB 151.3 kB/s eta 0:00:01
#      -------------------- ---------------- 92.2/167.0 kB 308.0 kB/s eta 0:00:01
#      ------------------------ ----------- 112.6/167.0 kB 364.4 kB/s eta 0:00:01
#      ------------------------ ----------- 112.6/167.0 kB 364.4 kB/s eta 0:00:01
#      -----------------------------------  163.8/167.0 kB 364.0 kB/s eta 0:00:01
#      ------------------------------------ 167.0/167.0 kB 346.1 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading kiwisolver-1.4.7-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------- ----------------------- 122.9/294.9 kB ? eta -:--:--
#    ---------------- ----------------------- 122.9/294.9 kB ? eta -:--:--
#    ---------------- ----------------------- 122.9/294.9 kB ? eta -:--:--
#    ---------------------- --------------- 174.1/294.9 kB 871.5 kB/s eta 0:00:01
#    ------------------------------------- -- 276.5/294.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.1 MB/s eta 0:00:00
# Downloading matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.8 MB 7.9 MB/s eta 0:00:01
#    - -------------------------------------- 0.3/7.8 MB 5.1 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/7.8 MB 5.1 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/7.8 MB 5.1 MB/s eta 0:00:02
#    --- ------------------------------------ 0.6/7.8 MB 2.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.9/7.8 MB 3.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/7.8 MB 3.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/7.8 MB 3.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.1/7.8 MB 2.7 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/7.8 MB 3.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.3/7.8 MB 4.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.3/7.8 MB 4.4 MB/s eta 0:00:02
#    ------------ --------------------------- 2.4/7.8 MB 4.0 MB/s eta 0:00:02
#    -------------- ------------------------- 2.9/7.8 MB 4.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.3/7.8 MB 4.7 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/7.8 MB 5.1 MB/s eta 0:00:01
#    -------------------- ------------------- 3.9/7.8 MB 5.0 MB/s eta 0:00:01
#    --------------------- ------------------ 4.2/7.8 MB 5.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/7.8 MB 5.3 MB/s eta 0:00:01
#    ------------------------- -------------- 5.0/7.8 MB 5.5 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/7.8 MB 5.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.7/7.8 MB 5.6 MB/s eta 0:00:01
#    ------------------------------- -------- 6.1/7.8 MB 5.7 MB/s eta 0:00:01
#    --------------------------------- ------ 6.6/7.8 MB 5.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.9/7.8 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------- -- 7.2/7.8 MB 6.0 MB/s eta 0:00:01
#    -------------------------------------- - 7.5/7.8 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.8 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  7.7/7.8 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  7.8/7.8 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  7.8/7.8 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 5.4 MB/s eta 0:00:00
# Downloading contourpy-1.3.0-cp312-cp312-win_amd64.whl (218 kB)
#    ---------------------------------------- 0.0/218.3 kB ? eta -:--:--
#    ---------------------------------------- 218.3/218.3 kB 6.7 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.54.1-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------------- -------------------------- 0.7/2.2 MB 15.3 MB/s eta 0:00:01
#    ------------------- -------------------- 1.1/2.2 MB 13.5 MB/s eta 0:00:01
#    ------------------------------ --------- 1.7/2.2 MB 11.8 MB/s eta 0:00:01
#    --------------------------------- ------ 1.9/2.2 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 7.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.7-cp312-cp312-win_amd64.whl (55 kB)
#    ---------------------------------------- 0.0/55.9 kB ? eta -:--:--
#    ---------------------------------------- 55.9/55.9 kB 1.4 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ----- ---------------------------------- 0.4/2.6 MB 7.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.7/2.6 MB 9.3 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.6 MB 7.7 MB/s eta 0:00:01
#    ------------------ --------------------- 1.2/2.6 MB 6.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.4/2.6 MB 6.4 MB/s eta 0:00:01
#    -------------------------- ------------- 1.7/2.6 MB 6.3 MB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.6 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.6 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.6 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 6.3 MB/s eta 0:00:00
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#    ---------------------------------------- 0.0/104.1 kB ? eta -:--:--
#    ---------------------------------------- 104.1/104.1 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.54.1 kiwisolver-1.4.7 matplotlib-3.9.2 pillow-10.4.0 pyparsing-3.1.4 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#pip install openpyxl

# %%
#Importing an excel
pd.read_excel("DiamondPricesData.xlsx")
# Out:
#        price  carat        cut color clarity  depth  table     x     y     z
# 0        326   0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1        326   0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2        327   0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3        334   0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4        335   0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   2757   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936   2757   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53937   2757   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53938   2757   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53939   2757   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#Turn my imported dataset in to a python dataframe
diamonds = pd.read_excel("DiamondPricesData.xlsx")

# %%
#View the imported dataframe
diamonds.head(10)
# Out:
#    price  carat        cut color clarity  depth  table     x     y     z
# 0    326   0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1    326   0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2    327   0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3    334   0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4    335   0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# 5    336   0.24  Very Good     J    VVS2    NaN   57.0  3.94  3.96  2.48
# 6    336   0.24  Very Good     I    VVS1   62.3   57.0  3.95  3.98  2.47
# 7    337   0.26  Very Good     H     SI1   61.9   55.0  4.07  4.11  2.53
# 8    337   0.22       Fair     E     VS2   65.1   61.0  3.87  3.78  2.49
# 9    338   0.23  Very Good     H     VS1   59.4   61.0  4.00  4.05  2.39

# %%
#View the imported dataframe
diamonds.tail()
# Out:
#        price  carat        cut color clarity  depth  table     x     y     z
# 53935   2757   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936   2757   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53937   2757   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53938   2757   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53939   2757   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64

# %%
diamonds
# Out:
#        price  carat        cut color clarity  depth  table     x     y     z
# 0        326   0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1        326   0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2        327   0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3        334   0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4        335   0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   2757   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936   2757   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53937   2757   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53938   2757   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53939   2757   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ## EDA ##

# %% [markdown]
# 1. Exploring the excel dataset 'diamonds'

# %%
# Looking at the diamonds dataframe
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   price    53940 non-null  int64
#  1   carat    53940 non-null  float64
#  2   cut      53940 non-null  object
#  3   color    53934 non-null  object
#  4   clarity  53940 non-null  object
#  5   depth    53926 non-null  float64
#  6   table    53940 non-null  float64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
# Check the descriptive statistics
diamonds.describe()
# Out:
#               price         carat         depth         table             x  \
# count  53940.000000  53940.000000  53926.000000  53940.000000  53940.000000
# mean    3932.799722      0.797940     61.749479     57.457184      5.731157
# std     3989.439738      0.474011      1.432661      2.234491      1.121761
# min      326.000000      0.200000     43.000000     43.000000      0.000000
# 25%      950.000000      0.400000     61.000000     56.000000      4.710000
# 50%     2401.000000      0.700000     61.800000     57.000000      5.700000
# 75%     5324.250000      1.040000     62.500000     59.000000      6.540000
# max    18823.000000      5.010000     79.000000     95.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
# Looking at descriptive stats of only one variable
diamonds["price"].describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %%
# Forcing python to give descriptive stats about "object" or "string" data
import numpy as np
diamonds.describe(include=object)
# Out:
# (53940, 10)

# %% [markdown]
# ## DATA EXPLORATION AND CLEANING
# ### diamonds dataset
#
# 1. Explore for missing data
# 2. Explore data distribution (normal or non-gaussian distribution)
# 3. Check for outliers

# %% [markdown]
# ### 1. Checking for missing values/data

# %%
#Check for missing information (null)
diamonds.isna()
# Out:
#        price  carat    cut  color  clarity  depth  table      x      y      z
# 0      False  False  False  False    False  False  False  False  False  False
# 1      False  False  False  False    False  False  False  False  False  False
# 2      False  False  False  False    False  False  False  False  False  False
# 3      False  False  False  False    False  False  False  False  False  False
# 4      False  False  False  False    False  False  False  False  False  False
# ...      ...    ...    ...    ...      ...    ...    ...    ...    ...    ...
# 53935  False  False  False  False    False  False  False  False  False  False
# 53936  False  False  False  False    False  False  False  False  False  False
# 53937  False  False  False  False    False  False  False  False  False  False
# 53938  False  False  False  False    False  False  False  False  False  False
# 53939  False  False  False  False    False  False  False  False  False  False
#
# [53940 rows x 10 columns]

# %%
#Count the number of missing information
diamonds.isna().sum()
# Out:
# price       0
# carat       0
# cut         0
# color       6
# clarity     0
# depth      14
# table       0
# x           0
# y           0
# z           0
# dtype: int64

# %% [markdown]
# ### Data distribution

# %% [markdown]
# Note: The data model assumes normal distribution
#
# 1. Inspect using visuals
# 2. Categorical data: Barplots
# 3. Continuous data: Histograms/boxplots
# 4. Using Q-Q plots (these show the expected normal distribution versus the reality)
# 5. Generate statistics
# 6. Continuous data: Shapiro-Wilk test (3-5000 samples)
# 7. Continuous and categorical data: Kolmogorov-Smirnov test (>5000 samples)
#
# If p-value > 0.05, you can conclude that  the data does not deviate from normal  distribution.

# %% [markdown]
# Checking outliers
# 1. Using descriptive statistics
# 2. Visually (boxplots, histograms, Q-Q plots)
# 3. Statistics (normal destribution)
# 4. Inter-quartile range (IQR)
#
# Handling outliers
# 1. Delete the outliers (if not more than 30% of the total dataset)
# 2. Set thresholds (set a limit for the min & maximum points)
# 3. Impute outliers with mean for normally disctributed data
# 4. Impute outliers with median if not normally disctributed data
#
# Handling missing data
# 1. Delete the outliers (if not more than 30% of the total dataset)
# 2. Impute missing data with zeros (if certain there was no information)
# 3. Impute with mean (if numerical values are normally disctributed)
# 4. Impute with median (if numerical values are not normally disctributed)
# 5. Impute with mode (for categorical data)

# %% [markdown]
# 1. Transform the dataset to subset the categorical data from the continuous data

# %%
#Subset the object variables (cut, color, clarity)
diamonds_cat = diamonds[["cut","color","clarity"]]

# %%
#Subset the continuous variables 
diamonds_cont = diamonds.drop(columns=['cut','color','clarity'])
diamonds_cont
# Out:
#        price  carat  depth  table     x     y     z
# 0        326   0.23   61.5   55.0  3.95  3.98  2.43
# 1        326   0.21   59.8   61.0  3.89  3.84  2.31
# 2        327   0.23   56.9   65.0  4.05  4.07  2.31
# 3        334   0.29   62.4   58.0  4.20  4.23  2.63
# 4        335   0.31   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   2757   0.72   60.8   57.0  5.75  5.76  3.50
# 53936   2757   0.72   63.1   55.0  5.69  5.75  3.61
# 53937   2757   0.70   62.8   60.0  5.66  5.68  3.56
# 53938   2757   0.86   61.0   58.0  6.15  6.12  3.74
# 53939   2757   0.75   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %% [markdown]
# 2. Visuals for categorical data

# %%
#Plotting for one all categorical variables
import matplotlib.pyplot as plt  #library for visuals
#First generate a function for the multiple barcharts
def PlotBarCharts(inpData, colsToPlot):
    # %matplotlib inline
    
    import matplotlib.pyplot as plt
    
    # Generating multiple subplots
    fig, subPlot=plt.subplots(nrows=1, ncols=len(colsToPlot), figsize=(20,5))
    fig.suptitle('Bar charts of: '+ str(colsToPlot))

    for colName, plotNumber in zip(colsToPlot, range(len(colsToPlot))):
        inpData.groupby(colName).size().plot(kind='bar',ax=subPlot[plotNumber])

# %%
#Use the above function to generate the barplots
PlotBarCharts(inpData=diamonds_cat, colsToPlot=['cut', 'color', 'clarity'])

# %% [markdown]
# 3. Visuals for Continuous data

# %%
#Using multiple histograms
diamonds_cont.hist(figsize=(18,10))
# Out:
# array([[<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'carat'}>,
#         <Axes: title={'center': 'depth'}>],
#        [<Axes: title={'center': 'table'}>, <Axes: title={'center': 'x'}>,
#         <Axes: title={'center': 'y'}>],
#        [<Axes: title={'center': 'z'}>, <Axes: >, <Axes: >]], dtype=object)

# %%
#OR one could use the entire diamonds dataframe and specify the columns to be plotted
diamonds.hist(['carat', 'depth', 'table','price', 'x','y','z'], figsize=(18,10))
# Out:
# array([[<Axes: title={'center': 'carat'}>,
#         <Axes: title={'center': 'depth'}>,
#         <Axes: title={'center': 'table'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: title={'center': 'x'}>,
#         <Axes: title={'center': 'y'}>],
#        [<Axes: title={'center': 'z'}>, <Axes: >, <Axes: >]], dtype=object)

# %%
#To generate a histogram for only one variable
diamonds_cont.hist(['price'], figsize=(18,10))
# Out:
# array([[<Axes: title={'center': 'price'}>]], dtype=object)

# %% [markdown]
# ### using boxplots to illustrate distribution and check for outliers

# %%
#Boxplot of the variable price
diamonds_cont.boxplot(['price'])
# Out:
# <Axes: >

# %% [markdown]
# 3. USING Q-Q PLOTS

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.3-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from statsmodels) (2.0.0)
# Collecting scipy!=1.9.2,>=1.8 (from statsmodels)
#   Downloading scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 660.6 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.8 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 358.4 kB/s eta 0:00:00
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from statsmodels) (2.2.2)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\dell\appdata\roaming\python\python312\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in c:\users\dell\appdata\roaming\python\python312\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.3-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.8 MB 3.2 MB/s eta 0:00:04
#    ---------------------------------------- 0.1/9.8 MB 1.3 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/9.8 MB 939.4 kB/s eta 0:00:11
#     --------------------------------------- 0.2/9.8 MB 1.2 MB/s eta 0:00:08
#     --------------------------------------- 0.2/9.8 MB 1.3 MB/s eta 0:00:08
#    - -------------------------------------- 0.3/9.8 MB 1.3 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/9.8 MB 1.3 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/9.8 MB 1.2 MB/s eta 0:00:08
#    -- ------------------------------------- 0.5/9.8 MB 1.3 MB/s eta 0:00:08
#    -- ------------------------------------- 0.6/9.8 MB 1.4 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/9.8 MB 1.4 MB/s eta 0:00:07
#    --- ------------------------------------ 0.7/9.8 MB 1.4 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/9.8 MB 1.4 MB/s eta 0:00:07
#    --- ------------------------------------ 0.9/9.8 MB 1.4 MB/s eta 0:00:07
#    --- ------------------------------------ 0.9/9.8 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/9.8 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.1/9.8 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.2/9.8 MB 1.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.2/9.8 MB 1.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.8 MB 1.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.4/9.8 MB 1.6 MB/s eta 0:00:06
#    ------ --------------------------------- 1.5/9.8 MB 1.5 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/9.8 MB 1.6 MB/s eta 0:00:06
#    ------ --------------------------------- 1.7/9.8 MB 1.6 MB/s eta 0:00:06
#    ------- -------------------------------- 1.7/9.8 MB 1.6 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.8 MB 1.6 MB/s eta 0:00:05
#    ------- -------------------------------- 1.9/9.8 MB 1.7 MB/s eta 0:00:05
#    -------- ------------------------------- 2.0/9.8 MB 1.7 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.8 MB 1.7 MB/s eta 0:00:05
#    --------- ------------------------------ 2.2/9.8 MB 1.7 MB/s eta 0:00:05
#    --------- ------------------------------ 2.3/9.8 MB 1.7 MB/s eta 0:00:05
#    --------- ------------------------------ 2.4/9.8 MB 1.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.5/9.8 MB 1.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.5/9.8 MB 1.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.7/9.8 MB 1.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.8/9.8 MB 1.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.8/9.8 MB 1.8 MB/s eta 0:00:04
#    ------------ --------------------------- 3.0/9.8 MB 1.8 MB/s eta 0:00:04
#    ------------ --------------------------- 3.1/9.8 MB 1.8 MB/s eta 0:00:04
#    ------------- -------------------------- 3.2/9.8 MB 1.9 MB/s eta 0:00:04
#    ------------- -------------------------- 3.3/9.8 MB 1.9 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/9.8 MB 1.9 MB/s eta 0:00:04
#    -------------- ------------------------- 3.5/9.8 MB 1.9 MB/s eta 0:00:04
#    -------------- ------------------------- 3.6/9.8 MB 1.9 MB/s eta 0:00:04
#    -------------- ------------------------- 3.6/9.8 MB 1.9 MB/s eta 0:00:04
#    --------------- ------------------------ 3.8/9.8 MB 1.9 MB/s eta 0:00:04
#    --------------- ------------------------ 3.9/9.8 MB 2.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.0/9.8 MB 2.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.2/9.8 MB 2.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.3/9.8 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.8 MB 2.1 MB/s eta 0:00:03
#    ------------------ --------------------- 4.6/9.8 MB 2.1 MB/s eta 0:00:03
#    ------------------- -------------------- 4.7/9.8 MB 2.1 MB/s eta 0:00:03
#    ------------------- -------------------- 4.9/9.8 MB 2.1 MB/s eta 0:00:03
#    -------------------- ------------------- 5.1/9.8 MB 2.2 MB/s eta 0:00:03
#    --------------------- ------------------ 5.2/9.8 MB 2.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.4/9.8 MB 2.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.6/9.8 MB 2.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.7/9.8 MB 2.2 MB/s eta 0:00:02
#    ------------------------ --------------- 5.9/9.8 MB 2.3 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.8 MB 2.3 MB/s eta 0:00:02
#    ------------------------- -------------- 6.2/9.8 MB 2.3 MB/s eta 0:00:02
#    ------------------------- -------------- 6.3/9.8 MB 2.4 MB/s eta 0:00:02
#    -------------------------- ------------- 6.5/9.8 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 6.7/9.8 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/9.8 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.0/9.8 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.2/9.8 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.3/9.8 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 7.5/9.8 MB 2.5 MB/s eta 0:00:01
#    ------------------------------- -------- 7.7/9.8 MB 2.5 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.8 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.8 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 8.3/9.8 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.5/9.8 MB 2.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.8 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 9.0/9.8 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.8 MB 2.8 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.8 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  9.8/9.8 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  9.8/9.8 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  9.8/9.8 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 2.8 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.9 kB ? eta -:--:--
#    -------------------------------------- - 225.3/233.9 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 233.9/233.9 kB 3.6 MB/s eta 0:00:00
# Downloading scipy-1.14.1-cp312-cp312-win_amd64.whl (44.5 MB)
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.4/44.5 MB 11.2 MB/s eta 0:00:04
#     --------------------------------------- 0.6/44.5 MB 9.6 MB/s eta 0:00:05
#     --------------------------------------- 0.9/44.5 MB 7.2 MB/s eta 0:00:07
#    - -------------------------------------- 1.2/44.5 MB 7.5 MB/s eta 0:00:06
#    - -------------------------------------- 1.5/44.5 MB 6.7 MB/s eta 0:00:07
#    - -------------------------------------- 1.7/44.5 MB 6.8 MB/s eta 0:00:07
#    - -------------------------------------- 2.0/44.5 MB 6.6 MB/s eta 0:00:07
#    -- ------------------------------------- 2.3/44.5 MB 6.6 MB/s eta 0:00:07
#    -- ------------------------------------- 2.6/44.5 MB 6.8 MB/s eta 0:00:07
#    -- ------------------------------------- 2.9/44.5 MB 6.6 MB/s eta 0:00:07
#    -- ------------------------------------- 3.2/44.5 MB 6.7 MB/s eta 0:00:07
#    --- ------------------------------------ 3.5/44.5 MB 6.8 MB/s eta 0:00:07
#    --- ------------------------------------ 3.7/44.5 MB 6.6 MB/s eta 0:00:07
#    --- ------------------------------------ 4.1/44.5 MB 6.7 MB/s eta 0:00:07
#    ---- ----------------------------------- 4.5/44.5 MB 7.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.7/44.5 MB 6.8 MB/s eta 0:00:06
#    ---- ----------------------------------- 5.0/44.5 MB 6.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 5.3/44.5 MB 7.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 5.7/44.5 MB 7.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 6.0/44.5 MB 7.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 6.4/44.5 MB 7.1 MB/s eta 0:00:06
#    ----- ---------------------------------- 6.7/44.5 MB 7.2 MB/s eta 0:00:06
#    ------ --------------------------------- 7.1/44.5 MB 7.2 MB/s eta 0:00:06
#    ------ --------------------------------- 7.4/44.5 MB 7.3 MB/s eta 0:00:06
#    ------ --------------------------------- 7.5/44.5 MB 7.1 MB/s eta 0:00:06
#    ------ --------------------------------- 7.6/44.5 MB 6.8 MB/s eta 0:00:06
#    ------ --------------------------------- 7.7/44.5 MB 6.6 MB/s eta 0:00:06
#    ------- -------------------------------- 7.8/44.5 MB 6.6 MB/s eta 0:00:06
#    ------- -------------------------------- 7.9/44.5 MB 6.3 MB/s eta 0:00:06
#    ------- -------------------------------- 8.0/44.5 MB 6.3 MB/s eta 0:00:06
#    ------- -------------------------------- 8.0/44.5 MB 5.9 MB/s eta 0:00:07
#    ------- -------------------------------- 8.0/44.5 MB 5.7 MB/s eta 0:00:07
#    ------- -------------------------------- 8.0/44.5 MB 5.5 MB/s eta 0:00:07
#    ------- -------------------------------- 8.0/44.5 MB 5.4 MB/s eta 0:00:07
#    ------- -------------------------------- 8.4/44.5 MB 5.4 MB/s eta 0:00:07
#    ------- -------------------------------- 8.8/44.5 MB 5.6 MB/s eta 0:00:07
#    -------- ------------------------------- 9.1/44.5 MB 5.6 MB/s eta 0:00:07
#    -------- ------------------------------- 9.2/44.5 MB 5.5 MB/s eta 0:00:07
#    -------- ------------------------------- 9.3/44.5 MB 5.5 MB/s eta 0:00:07
#    -------- ------------------------------- 9.6/44.5 MB 5.5 MB/s eta 0:00:07
#    -------- ------------------------------- 10.0/44.5 MB 5.6 MB/s eta 0:00:07
#    --------- ------------------------------ 10.4/44.5 MB 5.6 MB/s eta 0:00:07
#    --------- ------------------------------ 10.7/44.5 MB 5.6 MB/s eta 0:00:07
#    ---------- ----------------------------- 11.1/44.5 MB 5.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 11.4/44.5 MB 5.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 11.7/44.5 MB 5.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 12.0/44.5 MB 5.8 MB/s eta 0:00:06
#    ---------- ----------------------------- 12.0/44.5 MB 5.8 MB/s eta 0:00:06
#    ---------- ----------------------------- 12.0/44.5 MB 5.8 MB/s eta 0:00:06
#    ----------- ---------------------------- 13.2/44.5 MB 6.0 MB/s eta 0:00:06
#    ----------- ---------------------------- 13.2/44.5 MB 6.0 MB/s eta 0:00:06
#    ------------ --------------------------- 13.4/44.5 MB 5.7 MB/s eta 0:00:06
#    ------------ --------------------------- 13.7/44.5 MB 5.6 MB/s eta 0:00:06
#    ------------ --------------------------- 14.0/44.5 MB 5.7 MB/s eta 0:00:06
#    ------------ --------------------------- 14.0/44.5 MB 5.7 MB/s eta 0:00:06
#    ------------ --------------------------- 14.0/44.5 MB 5.7 MB/s eta 0:00:06
#    ------------- -------------------------- 14.5/44.5 MB 5.5 MB/s eta 0:00:06
#    ------------- -------------------------- 15.3/44.5 MB 5.8 MB/s eta 0:00:06
#    ------------- -------------------------- 15.4/44.5 MB 5.6 MB/s eta 0:00:06
#    -------------- ------------------------- 15.6/44.5 MB 5.6 MB/s eta 0:00:06
#    -------------- ------------------------- 15.9/44.5 MB 5.6 MB/s eta 0:00:06
#    -------------- ------------------------- 16.2/44.5 MB 5.6 MB/s eta 0:00:06
#    -------------- ------------------------- 16.4/44.5 MB 5.5 MB/s eta 0:00:06
#    -------------- ------------------------- 16.6/44.5 MB 5.5 MB/s eta 0:00:06
#    --------------- ------------------------ 16.9/44.5 MB 5.5 MB/s eta 0:00:06
#    --------------- ------------------------ 17.0/44.5 MB 5.4 MB/s eta 0:00:06
#    --------------- ------------------------ 17.2/44.5 MB 5.3 MB/s eta 0:00:06
#    --------------- ------------------------ 17.7/44.5 MB 5.4 MB/s eta 0:00:05
#    ---------------- ----------------------- 18.3/44.5 MB 7.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 18.8/44.5 MB 7.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 19.1/44.5 MB 6.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 19.4/44.5 MB 7.1 MB/s eta 0:00:04
#    ------------------ --------------------- 20.1/44.5 MB 7.3 MB/s eta 0:00:04
#    ------------------ --------------------- 20.5/44.5 MB 7.3 MB/s eta 0:00:04
#    ------------------ --------------------- 21.1/44.5 MB 7.4 MB/s eta 0:00:04
#    ------------------- -------------------- 21.5/44.5 MB 7.5 MB/s eta 0:00:04
#    ------------------- -------------------- 22.1/44.5 MB 7.7 MB/s eta 0:00:03
#    -------------------- ------------------- 22.5/44.5 MB 8.2 MB/s eta 0:00:03
#    -------------------- ------------------- 23.1/44.5 MB 8.1 MB/s eta 0:00:03
#    --------------------- ------------------ 23.7/44.5 MB 8.5 MB/s eta 0:00:03
#    --------------------- ------------------ 24.0/44.5 MB 8.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 24.5/44.5 MB 9.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 25.0/44.5 MB 9.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 25.3/44.5 MB 8.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 25.9/44.5 MB 9.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 26.2/44.5 MB 9.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 26.6/44.5 MB 9.8 MB/s eta 0:00:02
#    ------------------------ --------------- 27.0/44.5 MB 9.6 MB/s eta 0:00:02
#    ------------------------ --------------- 27.3/44.5 MB 10.2 MB/s eta 0:00:02
#    ------------------------ --------------- 27.7/44.5 MB 10.1 MB/s eta 0:00:02
#    ------------------------- -------------- 27.9/44.5 MB 10.1 MB/s eta 0:00:02
#    ------------------------- -------------- 28.1/44.5 MB 9.8 MB/s eta 0:00:02
#    ------------------------- -------------- 28.5/44.5 MB 9.5 MB/s eta 0:00:02
#    -------------------------- ------------- 29.0/44.5 MB 9.4 MB/s eta 0:00:02
#    -------------------------- ------------- 29.5/44.5 MB 9.6 MB/s eta 0:00:02
#    -------------------------- ------------- 29.8/44.5 MB 9.8 MB/s eta 0:00:02
#    --------------------------- ------------ 30.4/44.5 MB 9.5 MB/s eta 0:00:02
#    --------------------------- ------------ 30.6/44.5 MB 9.5 MB/s eta 0:00:02
#    --------------------------- ------------ 30.9/44.5 MB 9.2 MB/s eta 0:00:02
#    --------------------------- ------------ 31.1/44.5 MB 9.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 31.4/44.5 MB 9.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 31.9/44.5 MB 9.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 32.3/44.5 MB 8.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 32.6/44.5 MB 9.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.1/44.5 MB 8.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.4/44.5 MB 8.6 MB/s eta 0:00:02
#    ------------------------------ --------- 33.6/44.5 MB 8.3 MB/s eta 0:00:02
#    ------------------------------ --------- 33.7/44.5 MB 8.2 MB/s eta 0:00:02
#    ------------------------------ --------- 33.7/44.5 MB 8.2 MB/s eta 0:00:02
#    ------------------------------ --------- 33.9/44.5 MB 7.6 MB/s eta 0:00:02
#    ------------------------------ --------- 34.1/44.5 MB 7.4 MB/s eta 0:00:02
#    ------------------------------- -------- 34.8/44.5 MB 7.8 MB/s eta 0:00:02
#    -------------------------------- ------- 35.9/44.5 MB 8.1 MB/s eta 0:00:02
#    -------------------------------- ------- 36.4/44.5 MB 8.1 MB/s eta 0:00:02
#    -------------------------------- ------- 36.7/44.5 MB 8.0 MB/s eta 0:00:01
#    --------------------------------- ------ 37.1/44.5 MB 8.1 MB/s eta 0:00:01
#    --------------------------------- ------ 37.6/44.5 MB 8.3 MB/s eta 0:00:01
#    --------------------------------- ------ 37.8/44.5 MB 8.2 MB/s eta 0:00:01
#    --------------------------------- ------ 37.8/44.5 MB 8.2 MB/s eta 0:00:01
#    --------------------------------- ------ 37.8/44.5 MB 8.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.4/44.5 MB 8.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.7/44.5 MB 8.5 MB/s eta 0:00:01
#    ------------------------------------ --- 40.1/44.5 MB 8.4 MB/s eta 0:00:01
#    ------------------------------------ --- 40.3/44.5 MB 8.4 MB/s eta 0:00:01
#    ------------------------------------ --- 40.5/44.5 MB 8.3 MB/s eta 0:00:01
#    ------------------------------------ --- 40.6/44.5 MB 8.0 MB/s eta 0:00:01
#    ------------------------------------ --- 40.7/44.5 MB 7.9 MB/s eta 0:00:01
#    ------------------------------------ --- 40.9/44.5 MB 7.8 MB/s eta 0:00:01
#    ------------------------------------- -- 41.2/44.5 MB 7.7 MB/s eta 0:00:01
#    ------------------------------------- -- 41.5/44.5 MB 7.8 MB/s eta 0:00:01
#    ------------------------------------- -- 41.7/44.5 MB 7.6 MB/s eta 0:00:01
#    ------------------------------------- -- 41.7/44.5 MB 7.4 MB/s eta 0:00:01
#    ------------------------------------- -- 41.7/44.5 MB 7.2 MB/s eta 0:00:01
#    ------------------------------------- -- 41.8/44.5 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------- -- 41.8/44.5 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------- -- 41.9/44.5 MB 6.6 MB/s eta 0:00:01
#    ------------------------------------- -- 42.0/44.5 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 42.2/44.5 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 42.7/44.5 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 43.0/44.5 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 43.3/44.5 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  43.7/44.5 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.5 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.5 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 4.5 MB/s eta 0:00:00
# Installing collected packages: scipy, patsy, statsmodels
# Successfully installed patsy-0.5.6 scipy-1.14.1 statsmodels-0.14.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import necessary libraries
from numpy.random import seed, randn
from statsmodels.graphics.gofplots import qqplot
import matplotlib.pyplot as plt

# Set seed for reproducibility
seed(0)

# %%
#Plot distribution of the dataset using a Q-Q plot
#Import key libraries
from numpy.random import seed
from numpy.random import randn
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 5
#       3 from numpy.random import seed
#       4 from numpy.random import randn
# ----> 5 from statsmodels.graphics.gofplots import qqplot
#       6 from matplotlib import pyplot
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
# Sometimes, existing package conflicts can cause issues. Uninstalling and reinstalling statsmodels
pip uninstall statsmodels
pip install statsmodels
# Out:
#   Cell In[31], line 2
#     pip uninstall statsmodels
#         ^
# SyntaxError: invalid syntax

# %%
pip uninstall statsmodels

# %%
pip install statsmodels

# %%
#For categorical data
# seed the random number generator
seed(1)
# generate univariate observations
diamonds_cat = 5 * randn(100) + 50
# q-q plot
qqplot((diamonds_cat), line='s')
pyplot.show()

# %%
#For continuous data
# seed the random number generator
seed(1)
# generate univariate observations
diamonds_cont = 5 * randn(100) + 50
# q-q plot
qqplot((diamonds_cont), line='s')
pyplot.show()

# %% [markdown]
# 4. USING STATISTICAL TESTS

# %% [markdown]
# Note: The data model assumes that all variables are normally distributed
#
# If the p-value of these tests is greater than α = 0.05, then the data is assumed to be normally distributed.
#
# Null hypothesis (Ho) assumes that data is normally distributed (Gaussian) at p>0.05
#
# Alternative hypothesis (Ha) assumes the reverse

# %%
#Shapiro-Wilk works with less than 5000 samples
# Shapiro-Wilk Test
from scipy.stats import shapiro
# normality test for categorical variables
stat, p = shapiro(diamonds_cat)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret results
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (Accept H0)')
else:
    print('Sample does not look Gaussian (reject H0)')

# %%
# normality test for continuous variables
stat, p = shapiro(diamonds_cont)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret results
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (Accept H0)')
else:
    print('Sample does not look Gaussian (reject H0)')

# %%
#Alternatively just generate the Shapiro statistic which shows the relationship
#between the observations and the expected
#Normality test for price
from scipy import stats
res = stats.shapiro(diamonds_cont)
res.statistic

# %%
#OR
from scipy.stats import shapiro
#perform Shapiro-Wilk test
shapiro(diamonds_cont)

# %% [markdown]
# Result: There's a 99.2% similarity between the observed and expected.

# %% [markdown]
# However, the diamonds dataset has over 5000 samples, so we are supposed to use the K-S test for normality

# %%
#Do the same for "price" in the diamonds dataset
#First create an array of values from a normal distribution with mean and standard deviation of the "1945" variable
import numpy as np
price_norm = np.random.normal(np.mean(diamonds['price']), np.std(diamonds['price']), len(diamonds))

# %%
# plot the display of the distribution of price
import seaborn as sns

sns.ecdfplot(diamonds['price'], c='red')
sns.ecdfplot(price_norm, c='green')
# Out:
# <Axes: xlabel='price', ylabel='Proportion'>

# %% [markdown]
# Price doesn't look normally distributed above (red) but we can confirm with K-S test

# %%
# Confirm using the K-S test for normal distribution
from scipy.stats import kstest

result = (kstest(diamonds['price'], cdf='norm'))

print(f"K-S statistic: {result[0]}")
print(f"p-value: {result[1]}")
# Out:
# K-S statistic: 1.0
# p-value: 0.0

# %% [markdown]
# The K-statistic is 100% but..
# p-value is less than 0.05, confirming that Price isn't normally distributed

# %% [markdown]
# **D. CHECKING FOR OUTLIERS**

# %% [markdown]
# 1. Using descriptive stats
# 2. Visually (boxplots, histograms, Q-Q plots)
# 3. Statistics (Normal distribution)
# 4. Inter-quartile range (IQR)

# %%
#Using descriptive stats
diamonds.describe()
# Out:
#               price         carat         depth         table             x  \
# count  53940.000000  53940.000000  53926.000000  53940.000000  53940.000000
# mean    3932.799722      0.797940     61.749479     57.457184      5.731157
# std     3989.439738      0.474011      1.432661      2.234491      1.121761
# min      326.000000      0.200000     43.000000     43.000000      0.000000
# 25%      950.000000      0.400000     61.000000     56.000000      4.710000
# 50%     2401.000000      0.700000     61.800000     57.000000      5.700000
# 75%     5324.250000      1.040000     62.500000     59.000000      6.540000
# max    18823.000000      5.010000     79.000000     95.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %% [markdown]
# a. Look at the mean and maximum points for price (they're too far apart)
#
# b. The above is also apparent for carat, depth, table, x, y, z

# %%
#Visual inspection with boxplots
diamonds.boxplot(figsize=(18,10))
plt.show()

# %%
q3 = diamonds_cont.quantile(0.75)
q1 = diamonds_cont.quantile(0.25)
IQR = q3-q1
upper_bound = q3+IQR*1.5
lower_bound = q1-IQR*1.5

outliers = diamonds_cont['price'][((diamonds_cont['price']<lower_bound['price']) | (diamonds_cont['price']>upper_bound['price']))]
# outliers = outliers.shape[0]
# # Checking if outliers are less than 30% of the data so that we can delete it
# data_rows = diamonds.shape[0]
# percentage = (outliers/data_rows)*100
# upper_bound['price'], outliers, data_rows
outliers.max()
# Out:
# 18823

# %%
#Outliers can also be detected using IQR method which is more robust 
#Create a function to find outliers using IQR

def find_outliers_IQR(diamonds):

   q1=diamonds.quantile(0.25)

   q3=diamonds.quantile(0.75)

   IQR=q3-q1

   outliers = diamonds[((diamonds<(q1-1.5*IQR)) | (diamonds>(q3+1.5*IQR)))]

   return outliers

# %%
#Then use the above function to search for outliers in each variable e.g. price
outliers = find_outliers_IQR(diamonds["price"])

print("number of outliers: "+ str(len(outliers)))

print("max outlier value: "+ str(outliers.max()))

print("min outlier value: "+ str(outliers.min()))

outliers

# %% [markdown]
# Result: There are 3540 outliers in the variable price
#
# The maximum threshold is 18823 dollars
#
# The minimum threshold is 11886 dollars

# %%
#Run the same for more than one variable
outliers_all = find_outliers_IQR(diamonds[["depth","table","x","y","z"]])

outliers_all.sum()
# Out:
# depth    155766.20
# table     39230.00
# x           231.66
# y           283.43
# z           198.68
# dtype: float64

# %% [markdown]
# Points that show "NaN" illustrate no outlier, while those showing a number are an outlier

# %% [markdown]
# ## DATA CLEANING/TRANSFORMATION/ WRANGLING

# %% [markdown]
# 1. Handling outliers
#
# 2. Handling missing data
#
# 3. Other transformations (adding variables)

# %% [markdown]
# **A. HANDLING OUTLIERS**

# %% [markdown]
# 1. Delete the outliers (if no more than 30% of total dataset)
#
# 2. Set thresholds (set a limit for the minimum and maximum points)
#
# 3. Replace outliers that are missing data(imputation with mean for normal data, median for non-normal data)

# %%
# Delete outliers using the "drop.na" function
def drop_outliers_IQR(diamonds):

   q1=diamonds.quantile(0.25)

   q3=diamonds.quantile(0.75)

   IQR=q3-q1

   not_outliers = diamonds[~((diamonds<(q1-1.5*IQR)) | (diamonds>(q3+1.5*IQR)))]

   outliers_dropped = outliers.dropna().reset_index()

   return outliers_dropped

# %%
#Check the distribution of the dataset after dropping outliers
diamonds.boxplot(figsize=(20,8))
plt.show()

# %% [markdown]
# ### Exercise
# ### practice with the politician (Checking for outliers)

# %%
#Looking for outliers in the year 1945
outliers_politicians = find_outliers_IQR(politicians["1945"])

print("number of outliers: "+ str(len(outliers)))

print("max outlier value: "+ str(outliers.max()))

print("min outlier value: "+ str(outliers.min()))

outliers_politicians

# %% [markdown]
# **B. HANDLING MISSING DATA**
#
# 1. Remove the missing points if no more than 30% of dataset
#
# 2. Impute missing data with zeros (if certain there was no information)
#
# 3. Impute with mean (if numeric variables are normally distributed)
#
# 4. Impute with median (if numeric variables are not normally distributed)
#
# 5. Impute with mode (if variables are text/string/objects)

# %%
#For instance diamonds dataset has few missing observations
diamonds.isna().sum()
# Out:
# price       0
# carat       0
# cut         0
# color       6
# clarity     0
# depth      14
# table       0
# x           0
# y           0
# z           0
# dtype: int64

# %%
#Remove the missing info, then generate a new dataframe
diamonds_new = diamonds.dropna()
#Check to see if missing info is removed
diamonds_new.isna().sum()
# Out:
# price      0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
#Store the newly generated dataframe as a csv or excel
#diamonds_new is your dataframe
diamonds_new.to_csv("diamonds_new.csv", sep=',', encoding='utf-8', index=False)

# %%
#Store as excel
#requires openpyxl package
#df is your dataframe
diamonds_new.to_excel("diamonds_new.xlsx", sheet_name='Transformed Data', index=False)

# %% [markdown]
# ### Impute missing data with zeros
# ### Case study: politicians dataframe

# %%
#Justification: We are certain the missing data is an actuality, 
#also there's too much missing to be deleted
politicians.isna().sum()

# %%
#Replace the missing data with zero using "fillna"
politicians_new = politicians.fillna(0)
politicians_new.isna().sum()

# %%
#Imputing missing data with mode
#Case study: diamonds dataset
#Check for missing data
diamonds.isna().sum()

# %%
# Color is a categorical variable so we impute using mode
diamonds2 = diamonds['color'].fillna(value=diamonds['color'].mode(), inplace=True)

# %%
#To impute for depth which in the original dataset has outliers, we use median
diamonds3 = diamonds['depth'].fillna(value=diamonds['depth'].median(), inplace=True)

# %%
#Further transformation
#Adding a variable
#Add a variable called "price_by_carat" to the diamonds dataframe which is the price*carat
diamonds['price_by_carat'] = diamonds.apply(lambda row: (row.price*row.carat), axis = 1)
#Check the dataframe
# diamonds['price_by_carat'] = diamonds['price']*diamonds['carat']
# diamonds.drop(columns=['price_by_carat'], inplace=True)
diamonds
# Out:
#        price  carat        cut color clarity  depth  table     x     y     z  \
# 0        326   0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1        326   0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2        327   0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3        334   0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4        335   0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   2757   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936   2757   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53937   2757   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53938   2757   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53939   2757   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
#        price_by_carat
# 0               74.98
# 1               68.46
# 2               75.21
# 3               96.86
# 4              103.85
# ...               ...
# 53935         1985.04
# 53936         1985.04
# 53937         1929.90
# 53938         2371.02
# 53939         2067.75
#
# [53940 rows x 11 columns]
